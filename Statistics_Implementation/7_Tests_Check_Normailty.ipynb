# %% [markdown]
# Different Tests to check Normaity of the Data
# 1 : shapiro
# 2 : Normal Test
# 3 : Anderson

# %%
from scipy import stats
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-CompleteGuide/refs/heads/main/Iris.csv")

# %%
stats.shapiro(df['SepalWidthCm'])
# Out:
# ShapiroResult(statistic=np.float64(0.9837916445014413), pvalue=np.float64(0.07517918532015967))

# %% [markdown]
# Null_hypothesis is that my data is normally Distribured

# %%
p_value=0.07517918532015967

# %%
if p_value<=0.05:
    print("Reject Null Hypotheiss")
else:
    print("Accept null hypotheisis")
# Out:
# Accept null hypotheisis

# %%
import seaborn as sns
sns.displot(df['SepalWidthCm'],kde=True)

# %% [markdown]
# Normal Test

# %%
import numpy as np
from scipy import stats
d=np.random.lognormal(3,1,1000)
stats.normaltest(np.log(d))
# Out:
# NormaltestResult(statistic=np.float64(0.7110241755740573), pvalue=np.float64(0.7008144727717494))

# %% [markdown]
# Anderson Test

# %%
from scipy import stats
stats.anderson(np.log(d))
# Out:
# AndersonResult(statistic=np.float64(0.5529543693783125), critical_values=array([0.574, 0.653, 0.784, 0.914, 1.088]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=np.float64(2.9640668399094388), scale=np.float64(0.993961816398038))
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')
