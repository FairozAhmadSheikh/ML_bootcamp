# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
population=np.random.binomial(10,0.5,10000)
sns.displot(population)

# %%
log_normal=np.random.lognormal(10,0.5,10000)
sns.displot(log_normal)

# %% [markdown]
# Take Sample Now

# %%
SIZE=int(len(population)*0.30)
SIZE
# Out:
# 3000

# %% [markdown]
# Samples Now

# %%
# Samples size should be greater than 30    
# more sample size more it will be normally distributed
sample_means=[]
for i in range(1,31):
    sample=np.random.choice(population,size=SIZE)
    sample_means.append(np.mean(sample))

# %% [markdown]
# Sample Mean Distribution Plot

# %%
sns.displot(sample_means,kde=True)

# %%
# Samples size should be greater than 30    
# more sample size more it will be normally distributed
sample_means=[]
for i in range(1,51):
    sample=np.random.choice(population,size=SIZE)
    sample_means.append(np.mean(sample))
sns.displot(sample_means,kde=True)

# %%
# Samples size should be greater than 30    
# more sample size more it will be normally distributed
sample_means=[]
for i in range(1,101):
    sample=np.random.choice(population,size=SIZE)
    sample_means.append(np.mean(sample))
sns.displot(sample_means,kde=True)

# %%
# Samples size should be greater than 30    
# more sample size more it will be normally distributed
sample_means=[]
for i in range(1,151):
    sample=np.random.choice(population,size=SIZE)
    sample_means.append(np.mean(sample))
sns.displot(sample_means,kde=True)
